# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import astropy as astr
#from matplotlib import rc
import gaussfitter as gauss
#rc('font', **{'family':'serif','serif':['Times','Palatino']})
#rc('text', usetex=True)
from astropy.utils.data import download_file
from astropy.io import fits
from astropy.wcs import WCS
import sys
import re
import os

def source_box(data,x,y,boxsize):
    if (x-boxsize)<0:
        x_low=0
    else:
        x_low=x-boxsize
    if (x+boxsize)>data.shape[0]:
        x_high=data.shape[0]
    else:
        x_high=(x+boxsize)
    if (y-boxsize)<0:
        y_low=0
    else:
        y_low=(y-boxsize)
    if (y+boxsize)>data.shape[1]:
        y_high=data.shape[1]
    else:
        y_high=(y+boxsize)
    return data[y_low:y_high, x_low:x_high]
        

def write_psf_params(image_file, sources_file):
    
    #Part 1: download .fits file:
    print image_file
    hdu_list_image=fits.open(image_file)
    image_data=hdu_list_image[0].data
    print image_data.shape
    #Part 2: download .txt file, convert to pixel coordinates:
    nearby_sources=np.genfromtxt(sources_file, skip_header=23, usecols=(0,1))
    sources_data=pd.DataFrame(nearby_sources, columns=('RA', 'DEC'))
    w=WCS(image_file)
    px,py=w.all_world2pix(sources_data['RA'],sources_data['DEC'],1, tolerance=200.0)
    print px,py
    index=(np.arange(1,len(px)+1))
    pixels=zip(px,py,index)
    #print pixels[12]
    plt.figure()
    plt.imshow(np.log(image_data), cmap='gray_r')
    #plt.colorbar()
    #plt.plot(px,py,'rx', ms=10)
    plt.show()
    #Part 3: creating box around each source in the sources file:
    m=re.search('(.*)\.fits', image_file)
    
    output_file=open(m.group(1)+'.psf', 'w')
    for x,y,z in pixels:
        IMAGE_DATA=source_box(image_data,x,y,20.0)
        #print IMAGE_DATA
    #Part 4 & 5: find the Gaussian parameters and write them to a file:
        mpfit = gauss.gaussfit(IMAGE_DATA, returnmp=True)
        line=''
        print mpfit.params
        for param in mpfit.params:
            line += '{} '.format(param)
        line += '{}'.format(mpfit.errmsg)
        line += '\n'
        output_file.write(line)
        #gaussianfit=gauss.twodgaussian(mpfit.params)
        #plt.figure()
        #plt.imshow(IMAGE_DATA, cmap='gray_r')
        #plt.colorbar()
        #plt.contour(gaussianfit(*np.indices(IMAGE_DATA.shape)))
        #plt.show()
        #plt.savefig('{}/image{}.png'.format(m.group(1), z))
        #plt.clf()
        #this goes into the writing of the file mpfit.params
        #within the loop file.write(params)
    output_file.close()
    
#write_psf_params('KOI_284.fits', 'KOI284_Nearby.txt')
#image=fits.open('KOI_284.fits')
#print image

    
#write_psf_params('KOI_2704.fits', 'KOI2704_Nearby2.txt')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astropy.utils.data import download_file
from astropy.io import fits

#image=fits.open('./UKIRT_data/fits_Images/cfop_20141218_130031_morton/target1/Images/1Ic-dc20140206UKJ.fits')
#print image
#Note that these two lines above work, but if I try them below after the two functions and the for-loop, they do not work and give the same error as below

def return_fits(KOI):
    UKIRT_folder=os.listdir('UKIRT_data')
    Images_folder=os.listdir('./UKIRT_data/fits_Images')
    for filename in Images_folder:
        m=re.search('^(.*)\_morton$', filename)
        if m:
            KOI_fits=os.listdir('./UKIRT_data/fits_Images/{}/{}/Images'.format(filename,KOI))
            return KOI_fits
        
        
def return_src(KOI):
    UKIRT_folder=os.listdir('UKIRT_data')
    Sources_folder=os.listdir('./UKIRT_data/Sources')
    for filename in Sources_folder:
        n=re.search('^(.*)\_morton$', filename)
        if n:
            KOI_src=os.listdir('./UKIRT_data/Sources/{}/{}/Images'.format(filename, KOI))
            return KOI_src
print return_fits('target5')[0]
print return_src('target5')[0]
        
KOI_list=np.loadtxt('KOI_list.txt', dtype=str)
print KOI_list

for koi in KOI_list:
    if return_fits(koi)[0]=='.DS_Store':
        fits_file=str(return_fits(koi)[1])
    else:
        fits_file=str(return_fits(koi)[0])
    sources_file=str(return_src(koi)[0])
    #print fits_file, sources_file
    #write_psf_params('./UKIRT_data/fits_Images/cfop_20141218_130031_morton/{}/Images/{}'.format(koi, fits_file), './UKIRT_data/Sources/cfop_20141218_131440_morton/{}/Images/{}'.format(koi, sources_file))


    
    
write_psf_params('./UKIRT_data/fits_Images/cfop_20141218_130031_morton/target5834/Images/5834Ic-dc20140206UKJ.fits', './UKIRT_data/Sources/cfop_20141218_131440_morton/target5834/Images/5834Ic-dc20140206UKJ.src')
#image=fits.open('./UKIRT_data/fits_Images/cfop_20141218_130031_morton/target1/Images/1Ic-dc20140206UKJ.fits')
#print image
# Out:
# .DS_Store
# 5Ic-dc20140206UKJ.src
# ['target5' 'target571' 'target5710' ..., 'target1135' 'target1136'
#  'target1137']
# ./UKIRT_data/fits_Images/cfop_20141218_130031_morton/target5834/Images/5834Ic-dc20140206UKJ.fits
# (246, 301)
# [ 150.71540132  129.88274035   81.13532828  206.58642686  231.07654697
#    57.40584792  160.4922212    84.65070063  239.9328159   254.09698266
#   200.05597048  273.99553214] [  94.66098532  159.85217163   83.24351072   49.30637412   68.49968286
#   100.67592534  189.47479245   17.09304046   40.58349779  118.62664134
#   213.1065051    54.00338282]
# [  403.81693986  1361.85932454    19.70818259    19.64720922     2.23691434
#      2.07743293    17.14225992]
# [  4.14953247e+02   4.99260226e+03   1.98792676e+01   1.98448894e+01
#    2.24675180e+00   2.09028809e+00   2.94560842e+01]
# [ 400.45313646  184.7351184    19.11702613   19.23548495    2.25204464
#     2.08858554   11.25832542]
# [ 400.58223886  180.16793617   19.55083387   18.81875723    2.19874972
#     2.14226698    0.        ]
# [ 400.22650531   22.24739591   19.21638251   19.74179513    2.18814965
#     2.0342791    20.09890214]
# [  4.00301092e+02  -1.44093404e+01   2.29375953e+01   3.27604230e+00
#    3.02763311e-01   2.89599993e+00   1.09772421e+02]
# [ 400.21384262   21.53250619   19.52421363   19.39879769    1.18046409
#     1.94128148   67.25278078]
# [ 399.85407872    1.93826618    4.31640572   23.53126593    0.
#     4.12986701   76.98751183]
# [ 400.40594923  314.17072968   19.82240486   19.25045918    2.251263
#     2.18160009   30.0880121 ]
# [  3.99395372e+02   1.31254371e+06  -3.77711138e+02   2.69738687e+02
#    8.88273550e+01   2.35457796e+00   5.82124210e+01]
# [ 400.89793728  183.20897892   19.04403041   19.08815264    2.1878915
#     2.06877631    8.74622665]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-789003f3f840> in <module>()
#      42
#      43
# ---> 44 write_psf_params('./UKIRT_data/fits_Images/cfop_20141218_130031_morton/target5834/Images/5834Ic-dc20140206UKJ.fits', './UKIRT_data/Sources/cfop_20141218_131440_morton/target5834/Images/5834Ic-dc20140206UKJ.src')
#      45 #image=fits.open('./UKIRT_data/fits_Images/cfop_20141218_130031_morton/target1/Images/1Ic-dc20140206UKJ.fits')
#      46 #print image
#
# <ipython-input-45-29012d12d74a> in write_psf_params(image_file, sources_file)
#      64         #print IMAGE_DATA
#      65     #Part 4 & 5: find the Gaussian parameters and write them to a file:
# ---> 66         mpfit = gauss.gaussfit(IMAGE_DATA, returnmp=True)
#      67         line=''
#      68         print mpfit.params
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/gaussfitter/gaussfitter.pyc in gaussfit(data, err, params, autoderiv, return_error, circle, fixed, limitedmin, limitedmax, usemoment, minpars, maxpars, rotate, vheight, quiet, returnmp, returnfitimage, **kwargs)
#     218         params[usemoment] = moment[usemoment]
#     219     elif params == [] or len(params) == 0:
# --> 220         params = (moments(data, circle, rotate, vheight, **kwargs))
#     221     if not vheight:
#     222         # If vheight is not set, we set it for sub-function calls but fix the
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/gaussfitter/gaussfitter.pyc in moments(data, circle, rotate, vheight, estimator, angle_guess, **kwargs)
#      45     Y, X = np.indices(data.shape)  # python convention: reverse x,y np.indices
#      46     y = np.argmax((X*np.abs(data)).sum(axis=1)/total)
# ---> 47     x = np.argmax((Y*np.abs(data)).sum(axis=0)/total)
#      48     col = data[int(y), :]
#      49     # FIRST moment, not second!
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in argmax(a, axis)
#     930     except AttributeError:
#     931         return _wrapit(a, 'argmax', axis)
# --> 932     return argmax(axis)
#     933
#     934
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/numpy/ma/core.pyc in argmax(self, axis, fill_value, out)
#    4995             fill_value = maximum_fill_value(self._data)
#    4996         d = self.filled(fill_value).view(ndarray)
# -> 4997         return d.argmax(axis, out=out)
#    4998
#    4999
#
# ValueError: attempt to get argmax of an empty sequence
