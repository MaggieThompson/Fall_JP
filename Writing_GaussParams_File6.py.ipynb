# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import astropy as astr
#from matplotlib import rc
import gaussfitter as gauss
#rc('font', **{'family':'serif','serif':['Times','Palatino']})
#rc('text', usetex=True)
from astropy.utils.data import download_file
from astropy.io import fits
from astropy.wcs import WCS
import sys
import re
import os

def source_box(data,x,y,boxsize):
    if (x-boxsize)<0:
        x_low=0
    else:
        x_low=x-boxsize
    if (x+boxsize)>data.shape[0]:
        x_high=data.shape[0]
    else:
        x_high=(x+boxsize)
    if (y-boxsize)<0:
        y_low=0
    else:
        y_low=(y-boxsize)
    if (y+boxsize)>data.shape[1]:
        y_high=data.shape[1]
    else:
        y_high=(y+boxsize)
    return data[y_low:y_high, x_low:x_high]
        

def write_psf_params(image_file, sources_file):
    
    #Part 1: download .fits file:
    hdu_list_image=fits.open(image_file)
    image_data=hdu_list_image[0].data
    
    #Part 2: download .txt file, convert to pixel coordinates:
    nearby_sources=np.genfromtxt(sources_file, skip_header=23, usecols=(0,1))
    sources_data=pd.DataFrame(nearby_sources, columns=('RA', 'DEC'))
    #print sources_data
    w=WCS(image_file)
    px,py=w.all_world2pix(sources_data['RA'],sources_data['DEC'],1, tolerance=200.0)
    index=(np.arange(1,len(px)+1))
    pixels=zip(px,py,index)
    print pixels[12]
    #Part 3: creating box around each source in the sources file:
    m=re.search('(.*)\.fits', image_file)
    
    output_file=open(m.group(1)+'.psf', 'w')
    #os.mkdir(m.group(1))
    for x,y,z in pixels:
        IMAGE_DATA=source_box(image_data,x,y,20.0)
        #print IMAGE_DATA
    #Part 4 & 5: find the Gaussian parameters and write them to a file:
        mpfit = gauss.gaussfit(IMAGE_DATA, returnmp=True)
        line=''
        print mpfit.params
        for param in mpfit.params:
            line += '{} '.format(param)
        line += '{}'.format(mpfit.errmsg)
        line += '\n'
        output_file.write(line)
        gaussianfit=gauss.twodgaussian(mpfit.params)
        plt.figure()
        plt.imshow(IMAGE_DATA, cmap='gray_r')
        plt.colorbar()
        plt.contour(gaussianfit(*np.indices(IMAGE_DATA.shape)))
        #plt.show()
        plt.savefig('{}/image{}.png'.format(m.group(1), z))
        plt.clf()
        #this goes into the writing of the file mpfit.params
        #within the loop file.write(params)
    #plt.figure()
    #plt.imshow(np.log(image_data), cmap='gray_r')
    #plt.colorbar()
    #plt.plot(px,py,'rx', ms=10)
    #plt.show()
    output_file.close()
    
write_psf_params('KOI_284.fits', 'KOI284_Nearby.txt')

#write_psf_params('KOI_2704.fits', 'KOI2704_Nearby2.txt')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (288.43245015296361, 119.63146156949028, 13)
# [  4.79549814e+02   5.00631247e+04   2.00454085e+01   1.98163878e+01
#    1.62512576e+00   3.24766922e+00   0.00000000e+00]
# [  4.13549456e+02   2.81066617e+09   9.32487863e+00   1.94421767e+02
#    2.70500471e+01   6.24744661e+00   3.91738580e+00]
# [ 410.87925061   46.19782194   19.51332787   19.81486086    1.38953658
#     2.25521988   48.19038054]
# [ 410.92393187  218.64674201   19.86949801   19.25971848    1.52422301
#     1.86716809    0.        ]
# [ 411.13736491  271.66470422   19.33290458   19.0945256     1.46876792
#     1.80744496   13.4393947 ]
# [ 410.2793282    76.74915792   19.5605372    19.76181545    1.45183895
#     1.87035002   22.30089008]
# [ 410.6540189    90.67229811   19.87612355   19.21885689    1.46579053
#     2.03055528   17.13861271]
# [ 410.90198661  154.72520375   19.5477859    19.74465819    1.85085235
#     1.57740957   88.88231154]
# [ 411.24175397   40.17474518   20.19093273   19.37465774    1.26977013
#     1.69461396  120.67720788]
# [ 410.51979591  132.33335751   19.21132286   19.42491364    1.31559089
#     1.85183291    7.32888986]
# [ 410.58348425   42.75244152   19.54597579   19.56347981    0.7656593
#     2.05126323   35.04361933]
# [ 411.33182628  396.1274239    19.17964483   19.00740374    1.55921331
#     1.78450994   15.54727218]
# [ 410.90832666    2.60663187    4.73503864   20.47841354    1.08973443
#     0.           74.81721018]
# [ 410.71637391   30.65768367   20.00585511   19.21743036    1.578345
#     1.84419666    0.        ]
# [ 409.8099023    53.49110284   19.43310753    5.55214877    1.80336022
#     1.60537102  110.65182822]
# [ 410.68957398  138.50055082    2.7923163    19.35603281    1.78363386
#     1.53366168   98.65402571]

# %%
def return_fits(KOI):
    UKIRT_folder=os.listdir('UKIRT_data')
    Images_folder=os.listdir('./UKIRT_data/fits_Images')
    for filename in Images_folder:
        m=re.search('(.*)\_morton$', filename)
        if m:
            for target in filename:
                KOI_fits=os.listdir('./UKIRT_data/fits_Images/{}/{}/Images'.format(filename,KOI))
                return KOI_fits
        
def return_src(KOI):
    UKIRT_folder=os.listdir('UKIRT_data')
    Sources_folder=os.listdir('./UKIRT_data/Sources')
    for filename in Sources_folder:
        n=re.search('(.*)\_morton$', filename)
        if n:
            KOI_src=os.listdir('./UKIRT_data/Sources/{}/{}/Images'.format(filename, KOI))
            return KOI_src
KOI_list=np.loadtxt('KOI_list.txt', dtype=str)
print KOI_list

FITS_Images=[]       
for x in KOI_list:
    FITS_Image=return_fits(x)
    FITS_Images.append(FITS_Image)

SOURCE_Files=[]
for y in KOI_list:
    SOURCE_File=return_src(y)
    SOURCE_Files.append(SOURCE_File)

#files=zip(FITS_Images,SOURCE_Files)
#print files


for x,y in zip(FITS_Images,SOURCE_Files):
    #print x,y
    write_psf_params(x,y)
    
write_psf_params('929Ic-dc20140206UKJ.fits', '929Ic-dc20140206UKJ.src')
# Out:
# ['target5' 'target571' 'target5710' ..., 'target1135' 'target1136'
#  'target1137']
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-101-f20a86b96e8d> in <module>()
#      36 for x,y in zip(FITS_Images,SOURCE_Files):
#      37     #print x,y
# ---> 38     write_psf_params(x,y)
#      39
#      40 write_psf_params('929Ic-dc20140206UKJ.fits', '929Ic-dc20140206UKJ.src')
#
# <ipython-input-3-a91bbb9ffa59> in write_psf_params(image_file, sources_file)
#      38
#      39     #Part 1: download .fits file:
# ---> 40     hdu_list_image=fits.open(image_file)
#      41     image_data=hdu_list_image[0].data
#      42
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in fitsopen(name, mode, memmap, save_backup, **kwargs)
#     116         raise ValueError('Empty filename: %s' % repr(name))
#     117
# --> 118     return HDUList.fromfile(name, mode, memmap, save_backup, **kwargs)
#     119
#     120
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in fromfile(cls, fileobj, mode, memmap, save_backup, **kwargs)
#     248
#     249         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
# --> 250                              save_backup=save_backup, **kwargs)
#     251
#     252     @classmethod
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in _readfrom(cls, fileobj, data, mode, memmap, save_backup, **kwargs)
#     759             if not isinstance(fileobj, _File):
#     760                 # instantiate a FITS file object (ffo)
# --> 761                 ffo = _File(fileobj, mode=mode, memmap=memmap)
#     762             else:
#     763                 ffo = fileobj
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/astropy/io/fits/file.pyc in __init__(self, fileobj, mode, memmap, clobber)
#     148             self._open_filename(fileobj, mode, clobber)
#     149         else:
# --> 150             self._open_filelike(fileobj, mode, clobber)
#     151
#     152         if isinstance(fileobj, gzip.GzipFile):
#
# /Users/maggiethompson/anaconda/lib/python2.7/site-packages/astropy/io/fits/file.pyc in _open_filelike(self, fileobj, mode, clobber)
#     421             raise IOError("File-like object does not have a 'write' "
#     422                           "method, required for mode '%s'."
# --> 423                           % self.mode)
#     424
#     425         # Any mode except for 'ostream' requires readability
#
# IOError: File-like object does not have a 'write' method, required for mode 'ostream'.
